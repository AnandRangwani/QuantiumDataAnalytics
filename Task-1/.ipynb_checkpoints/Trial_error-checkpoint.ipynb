# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns

# %%
df=pd.read_csv('new.csv',index_col=0)

# %%
df.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
#
#    PROD_WEIGHT_SIZE
# 0               175
# 1               175
# 2               170
# 3               175
# 4               150

# %%
lst=list(df.PROD_NAME)
len(lst)
lst[23]
# Out:
# 'Kettle Sea Salt     And Vinegar 175g'

# %%
ls=[]

for i in lst:
    lst1=re.findall(r'[cC][hH]+[iI]*[cC]*[kK]{0,2}[ieIE]*[nN]',i)
    if len(lst1)==0:
        lst1=re.findall(r'[Ss][oO][uU][rR]\s?|[Cc][rR][eE]?[aA]?[mM]\s?\&|\&?[Oo][nN][iI][oO]?[nN]',i)
    else:
        ls.append('Chicken_flavour')
        continue
    if len(lst1)==0:
        lst1=re.findall(r'[cC][hH]+[iI]*[lL]+[ieIEyY]+|[Ss][pP][iI]*[Cc][yYiIeE]+|[Jj][eaA]*[lL]+[eaA]*[pP]+[iIeEn]+[n]*[o]*',i)
    else:
        ls.append('Sour_Cream/Onion')
        continue
    if len(lst1)==0:
        lst1=re.findall(r'[cC][hH]+[eE]*[zZsS]+[eyEY]+|[Mm][oO]?[z]+[a]?[r]+[e]*[l]+[a]+',i)
    else:
        ls.append('Chilli')
        continue
    if len(lst1)==0:
        lst1=re.findall(r'[Ss][Aa]*[Ll][tT][yY]*',i)
    else:
        ls.append('Cheese')
        continue
    if len(lst1)==0:
        lst1=re.findall(r'[Tt][oO]?[mM][aA]?[tT][oO]|[Tt][aA][nN][gG][iIyY]',i)
    else:
        ls.append('Salty')
        continue
    if len(lst1)==0:
        ls.append('Other_flavour')
    else:
        ls.append('Tomato/Tangy')

# %%
PROD_FLAVOUR=pd.Series(ls)

# %%
PROD_FLAVOUR.value_counts()
# Out:
# Other_flavour       89700
# Salty               38564
# Chilli              33124
# Cheese              32652
# Chicken_flavour     30793
# Sour_Cream/Onion    26002
# Tomato/Tangy        14001
# dtype: int64

# %%
df.PROD_NAME
# Out:
# 0           Natural Chip        Compny SeaSalt175g
# 1                         CCs Nacho Cheese    175g
# 2           Smiths Crinkle Cut  Chips Chicken 170g
# 3           Smiths Chip Thinly  S/Cream&Onion 175g
# 4         Kettle Tortilla ChpsHny&Jlpno Chili 150g
#                             ...
# 264831     Kettle Sweet Chilli And Sour Cream 175g
# 264832               Tostitos Splash Of  Lime 175g
# 264833                    Doritos Mexicana    170g
# 264834     Doritos Corn Chip Mexican Jalapeno 150g
# 264835               Tostitos Splash Of  Lime 175g
# Name: PROD_NAME, Length: 264836, dtype: object

# %%
df['PROD_FLAVOUR']=PROD_FLAVOUR

# %%
df.head(20)
# Out:
#      DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0   43390          1            1000       1         5
# 1   43599          1            1307     348        66
# 2   43605          1            1343     383        61
# 3   43329          2            2373     974        69
# 4   43330          2            2426    1038       108
# 5   43604          4            4074    2982        57
# 6   43601          4            4149    3333        16
# 7   43601          4            4196    3539        24
# 8   43332          5            5026    4525        42
# 9   43330          7            7150    6900        52
# 10  43602          7            7215    7176        16
# 11  43332          8            8294    8221       114
# 12  43603          9            9208    8634        15
# 13  43329         13           13213   12447        92
# 14  43600         19           19272   16686        44
# 15  43604         20           20164   17136        54
# ...

# %%
df.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES  PROD_WEIGHT_SIZE
# count  264836.000000  264836.000000  264836.000000     264836.000000
# mean       56.583157       1.907309       7.304200        182.427004
# std        32.826638       0.643654       3.083226         64.327196
# min         1.000000       1.000000       1.500000         70.000000
# ...

# %%
df[df.TOT_SALES>3*np.percentile(df.TOT_SALES,[99.99])[0]]
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762  43331        226          226000  226201         4
# 69763  43605        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES  \
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0
#
#        PROD_WEIGHT_SIZE   PROD_FLAVOUR
# 69762               380  Other_flavour
# 69763               380  Other_flavour

# %%
df_new=df.loc[df.TOT_SALES!=650,:]

# %%
df_new.describe()
# Out:
#                 DATE      STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264834.000000  264834.000000    2.648340e+05  2.648340e+05
# mean    43464.036230     135.079423    1.355488e+05  1.351576e+05
# std       105.389007      76.784063    8.057990e+04  7.813292e+04
# min     43282.000000       1.000000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.000000    7.002100e+04  6.760050e+04
# 50%     43464.000000     130.000000    1.303570e+05  1.351365e+05
# 75%     43555.000000     203.000000    2.030940e+05  2.026998e+05
# max     43646.000000     272.000000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES  PROD_WEIGHT_SIZE
# count  264834.000000  264834.000000  264834.000000     264834.000000
# mean       56.583554       1.905813       7.299346        182.425512
# std        32.826444       0.343436       2.527241         64.325148
# min         1.000000       1.000000       1.500000         70.000000
# ...

# %%
df_new[(df.LYLTY_CARD_NBR==226000)]
# Out:
# <ipython-input-15-cba689c3f4af>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_new[(df.LYLTY_CARD_NBR==226000)]
# Empty DataFrame
# Columns: [DATE, STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PROD_WEIGHT_SIZE, PROD_FLAVOUR]
# Index: []

# %%
df_new.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
#
#    PROD_WEIGHT_SIZE      PROD_FLAVOUR
# 0               175             Salty
# 1               175            Cheese
# 2               170   Chicken_flavour
# 3               175  Sour_Cream/Onion
# 4               150            Chilli

# %%
df[df.LYLTY_CARD_NBR==226000]
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762  43331        226          226000  226201         4
# 69763  43605        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES  \
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0
#
#        PROD_WEIGHT_SIZE   PROD_FLAVOUR
# 69762               380  Other_flavour
# 69763               380  Other_flavour

# %%
df_transaction=df_new

# %%
df_customer=pd.read_csv('QVI_purchase_behaviour.csv',index_col=0)

# %%
df_customer.head()
# Out:
#                              LIFESTAGE PREMIUM_CUSTOMER
# LYLTY_CARD_NBR
# 1000             YOUNG SINGLES/COUPLES          Premium
# 1002             YOUNG SINGLES/COUPLES       Mainstream
# 1003                    YOUNG FAMILIES           Budget
# 1004             OLDER SINGLES/COUPLES       Mainstream
# 1005            MIDAGE SINGLES/COUPLES       Mainstream

# %%
df_try=df_transaction.join(df_customer,on=df_transaction.LYLTY_CARD_NBR)

# %%
df_try.head(30)
# Out:
#      DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0   43390          1            1000       1         5
# 1   43599          1            1307     348        66
# 2   43605          1            1343     383        61
# 3   43329          2            2373     974        69
# 4   43330          2            2426    1038       108
# 5   43604          4            4074    2982        57
# 6   43601          4            4149    3333        16
# 7   43601          4            4196    3539        24
# 8   43332          5            5026    4525        42
# 9   43330          7            7150    6900        52
# 10  43602          7            7215    7176        16
# 11  43332          8            8294    8221       114
# 12  43603          9            9208    8634        15
# 13  43329         13           13213   12447        92
# 14  43600         19           19272   16686        44
# 15  43604         20           20164   17136        54
# ...

# %%
df_try.isnull().sum()
# Out:
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PROD_WEIGHT_SIZE    0
# PROD_FLAVOUR        0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df_try[(df_try.PROD_FLAVOUR.isnull())]
# Out:
# Empty DataFrame
# Columns: [DATE, STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PROD_WEIGHT_SIZE, PROD_FLAVOUR, LIFESTAGE, PREMIUM_CUSTOMER]
# Index: []

# %%
df_final=pd.read_csv('cleaned_data.csv',index_col=0)
df_final.isnull().sum()
# Out:
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PROD_WEIGHT_SIZE    0
# PROD_FLAVOUR        2
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df_final=df_try
df_final.to_csv('cleaned_data.csv')

# %%
df_final.isnull().sum()
# Out:
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PROD_WEIGHT_SIZE    0
# PROD_FLAVOUR        0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64
