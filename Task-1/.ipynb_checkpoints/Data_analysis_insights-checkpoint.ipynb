# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Cleaned_merged_data.csv',index_col=0)
df.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PROD_WEIGHT  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0          175
# 1                  CCs Nacho Cheese    175g         3        6.3          175
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9          170
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0          175
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8          150
#
#        PROD_FLAVOUR               LIFESTAGE PREMIUM_CUSTOMER
# 0             Salty   YOUNG SINGLES/COUPLES          Premium
# 1            Cheese  MIDAGE SINGLES/COUPLES           Budget
# 2   Chicken_flavour  MIDAGE SINGLES/COUPLES           Budget
# 3  Sour_Cream/Onion  MIDAGE SINGLES/COUPLES           Budget
# 4            Chilli  MIDAGE SINGLES/COUPLES           Budget

# %% [markdown]
# ### To find out which product is expensive and which one is relatively cheaper , we need to calculate price per 100 grams of product

# %%
df['PricePer100g']=((df['TOT_SALES']/df['PROD_QTY'])*100)/df['PROD_WEIGHT']

# %%
df.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PROD_WEIGHT  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0          175
# 1                  CCs Nacho Cheese    175g         3        6.3          175
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9          170
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0          175
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8          150
#
#        PROD_FLAVOUR               LIFESTAGE PREMIUM_CUSTOMER  PricePer100g
# 0             Salty   YOUNG SINGLES/COUPLES          Premium      1.714286
# 1            Cheese  MIDAGE SINGLES/COUPLES           Budget      1.200000
# 2   Chicken_flavour  MIDAGE SINGLES/COUPLES           Budget      0.852941
# 3  Sour_Cream/Onion  MIDAGE SINGLES/COUPLES           Budget      1.714286
# 4            Chilli  MIDAGE SINGLES/COUPLES           Budget      3.066667

# %% [markdown]
# # We will try to find out that what category of customers are of greater concern for the supermarket , and will try to analyse their choice of flavours of chips.
#
#
#
# ### For a super-market store the customers of concern are the type of customers that visit the store regularly and purchase goods in a good quantity, therefore along with the avg price of product that a customer of a particular category buys , we also need to see that on an avg, how many transactions a customer of a particular category does , and also on an avg how many packets of chips does a customer of a particular category, buys in one transaction.

# %% [markdown]
# ### First we have to find out that how many transactions are done by different category of customers

# %%
df_1=pd.DataFrame(df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['DATE'].count())
df_1.reset_index(inplace=True)
df_1.rename(columns={'DATE':'COUNT'},inplace=True)
df_1
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  COUNT
# 0            Budget  MIDAGE SINGLES/COUPLES   5020
# 1            Budget            NEW FAMILIES   3005
# 2            Budget          OLDER FAMILIES  23160
# 3            Budget   OLDER SINGLES/COUPLES  18407
# 4            Budget                RETIREES  15201
# 5            Budget          YOUNG FAMILIES  19122
# 6            Budget   YOUNG SINGLES/COUPLES   9242
# 7        Mainstream  MIDAGE SINGLES/COUPLES  11874
# 8        Mainstream            NEW FAMILIES   2325
# 9        Mainstream          OLDER FAMILIES  14244
# 10       Mainstream   OLDER SINGLES/COUPLES  18318
# 11       Mainstream                RETIREES  21466
# 12       Mainstream          YOUNG FAMILIES  12907
# 13       Mainstream   YOUNG SINGLES/COUPLES  20854
# 14          Premium  MIDAGE SINGLES/COUPLES   8216
# 15          Premium            NEW FAMILIES   1589
# 16          Premium          OLDER FAMILIES  11190
# 17          Premium   OLDER SINGLES/COUPLES  17754
# 18          Premium                RETIREES  13096
# 19          Premium          YOUNG FAMILIES  11563
# 20          Premium   YOUNG SINGLES/COUPLES   6281

# %% [markdown]
# ### We also have to find out that how many different customers of a particular category have purchased chips.

# %%
df_customer=pd.read_csv('QVI_purchase_behaviour.csv')
df_customer.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
df_2=pd.DataFrame(df_customer.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['LYLTY_CARD_NBR'].count())
df_2.reset_index(inplace=True)
df_2.rename(columns={'LYLTY_CARD_NBR':'COUNTS'},inplace=True)
df_2
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  COUNTS
# 0            Budget  MIDAGE SINGLES/COUPLES    1504
# 1            Budget            NEW FAMILIES    1112
# 2            Budget          OLDER FAMILIES    4675
# 3            Budget   OLDER SINGLES/COUPLES    4929
# 4            Budget                RETIREES    4454
# 5            Budget          YOUNG FAMILIES    4017
# 6            Budget   YOUNG SINGLES/COUPLES    3779
# 7        Mainstream  MIDAGE SINGLES/COUPLES    3340
# 8        Mainstream            NEW FAMILIES     849
# 9        Mainstream          OLDER FAMILIES    2831
# 10       Mainstream   OLDER SINGLES/COUPLES    4930
# 11       Mainstream                RETIREES    6479
# 12       Mainstream          YOUNG FAMILIES    2728
# 13       Mainstream   YOUNG SINGLES/COUPLES    8088
# 14          Premium  MIDAGE SINGLES/COUPLES    2431
# 15          Premium            NEW FAMILIES     588
# 16          Premium          OLDER FAMILIES    2274
# 17          Premium   OLDER SINGLES/COUPLES    4750
# 18          Premium                RETIREES    3872
# 19          Premium          YOUNG FAMILIES    2433
# 20          Premium   YOUNG SINGLES/COUPLES    2574

# %% [markdown]
# ### Finding the average number of transactions a customer of a particular category does.

# %%
df_3=pd.DataFrame(df_1['COUNT']/df_2['COUNTS'])
df_3.rename(columns={0:'#Transactions_Per_customer'},inplace=True)
df_4=pd.concat([df_2,df_3],axis=1)
df_4.drop('COUNTS',axis=1,inplace=True)
df_4
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  #Transactions_Per_customer
# 0            Budget  MIDAGE SINGLES/COUPLES                    3.337766
# 1            Budget            NEW FAMILIES                    2.702338
# 2            Budget          OLDER FAMILIES                    4.954011
# 3            Budget   OLDER SINGLES/COUPLES                    3.734429
# 4            Budget                RETIREES                    3.412887
# 5            Budget          YOUNG FAMILIES                    4.760269
# 6            Budget   YOUNG SINGLES/COUPLES                    2.445621
# 7        Mainstream  MIDAGE SINGLES/COUPLES                    3.555090
# 8        Mainstream            NEW FAMILIES                    2.738516
# 9        Mainstream          OLDER FAMILIES                    5.031438
# 10       Mainstream   OLDER SINGLES/COUPLES                    3.715619
# 11       Mainstream                RETIREES                    3.313166
# 12       Mainstream          YOUNG FAMILIES                    4.731305
# 13       Mainstream   YOUNG SINGLES/COUPLES                    2.578388
# 14          Premium  MIDAGE SINGLES/COUPLES                    3.379679
# 15          Premium            NEW FAMILIES                    2.702381
# 16          Premium          OLDER FAMILIES                    4.920844
# 17          Premium   OLDER SINGLES/COUPLES                    3.737684
# 18          Premium                RETIREES                    3.382231
# 19          Premium          YOUNG FAMILIES                    4.752569
# 20          Premium   YOUNG SINGLES/COUPLES                    2.440171

# %% [markdown]
# ### We also need to find out that on an average how many packets of chips does a customer of a particular category purchases in one transaction.

# %%
avg_packets=pd.DataFrame(df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE']).sum())
avg_packets.reset_index(inplace=True)
df_4['#packets_per_transaction']=avg_packets['PROD_QTY']/df_1['COUNT']
df_4
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  #Transactions_Per_customer  \
# 0            Budget  MIDAGE SINGLES/COUPLES                    3.337766
# 1            Budget            NEW FAMILIES                    2.702338
# 2            Budget          OLDER FAMILIES                    4.954011
# 3            Budget   OLDER SINGLES/COUPLES                    3.734429
# 4            Budget                RETIREES                    3.412887
# 5            Budget          YOUNG FAMILIES                    4.760269
# 6            Budget   YOUNG SINGLES/COUPLES                    2.445621
# 7        Mainstream  MIDAGE SINGLES/COUPLES                    3.555090
# 8        Mainstream            NEW FAMILIES                    2.738516
# 9        Mainstream          OLDER FAMILIES                    5.031438
# 10       Mainstream   OLDER SINGLES/COUPLES                    3.715619
# 11       Mainstream                RETIREES                    3.313166
# 12       Mainstream          YOUNG FAMILIES                    4.731305
# 13       Mainstream   YOUNG SINGLES/COUPLES                    2.578388
# 14          Premium  MIDAGE SINGLES/COUPLES                    3.379679
# 15          Premium            NEW FAMILIES                    2.702381
# 16          Premium          OLDER FAMILIES                    4.920844
# 17          Premium   OLDER SINGLES/COUPLES                    3.737684
# 18          Premium                RETIREES                    3.382231
# 19          Premium          YOUNG FAMILIES                    4.752569
# 20          Premium   YOUNG SINGLES/COUPLES                    2.440171
#
#     #packets_per_transaction
# 0                   1.891633
# 1                   1.853910
# 2                   1.945812
# 3                   1.913403
# 4                   1.892244
# 5                   1.940749
# 6                   1.803830
# 7                   1.911656
# 8                   1.857634
# 9                   1.948610
# 10                  1.910525
# 11                  1.887543
# 12                  1.940342
# 13                  1.852498
# 14                  1.889727
# 15                  1.860919
# 16                  1.945576
# 17                  1.914273
# 18                  1.900122
# 19                  1.937732
# 20                  1.804012

# %% [markdown]
# ### Finding avg price of product that a customer of a particular category purchases.

# %%
avg_price=pd.DataFrame(df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE']).sum())
avg_price.reset_index(inplace=True)
df_4['avg_price_product']=avg_price['PricePer100g']/df_1['COUNT']
df_4
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  #Transactions_Per_customer  \
# 0            Budget  MIDAGE SINGLES/COUPLES                    3.337766
# 1            Budget            NEW FAMILIES                    2.702338
# 2            Budget          OLDER FAMILIES                    4.954011
# 3            Budget   OLDER SINGLES/COUPLES                    3.734429
# 4            Budget                RETIREES                    3.412887
# 5            Budget          YOUNG FAMILIES                    4.760269
# 6            Budget   YOUNG SINGLES/COUPLES                    2.445621
# 7        Mainstream  MIDAGE SINGLES/COUPLES                    3.555090
# 8        Mainstream            NEW FAMILIES                    2.738516
# 9        Mainstream          OLDER FAMILIES                    5.031438
# 10       Mainstream   OLDER SINGLES/COUPLES                    3.715619
# 11       Mainstream                RETIREES                    3.313166
# 12       Mainstream          YOUNG FAMILIES                    4.731305
# 13       Mainstream   YOUNG SINGLES/COUPLES                    2.578388
# 14          Premium  MIDAGE SINGLES/COUPLES                    3.379679
# 15          Premium            NEW FAMILIES                    2.702381
# 16          Premium          OLDER FAMILIES                    4.920844
# 17          Premium   OLDER SINGLES/COUPLES                    3.737684
# 18          Premium                RETIREES                    3.382231
# 19          Premium          YOUNG FAMILIES                    4.752569
# 20          Premium   YOUNG SINGLES/COUPLES                    2.440171
#
#     #packets_per_transaction  avg_price_product
# 0                   1.891633           2.208977
# 1                   1.853910           2.315103
# 2                   1.945812           2.185014
# 3                   1.913403           2.279435
# 4                   1.892244           2.293559
# 5                   1.940749           2.196196
# 6                   1.803830           2.150231
# 7                   1.911656           2.323948
# 8                   1.857634           2.304687
# 9                   1.948610           2.186601
# 10                  1.910525           2.240537
# 11                  1.887543           2.252479
# 12                  1.940342           2.183497
# 13                  1.852498           2.366797
# 14                  1.889727           2.212461
# 15                  1.860919           2.282236
# 16                  1.945576           2.180378
# 17                  1.914273           2.270361
# 18                  1.900122           2.296230
# 19                  1.937732           2.208919
# 20                  1.804012           2.155132

# %% [markdown]
# ### Finding what contribution does each category of customers make in Total Sales of chips

# %%
df_5=pd.DataFrame(df.groupby(['PREMIUM_CUSTOMER','LIFESTAGE'])['TOT_SALES'].sum())
df_5=df_5.reset_index()
df_5['PERCENT_OF_TOT']=(df_5.TOT_SALES/df.TOT_SALES.sum())*100
df_5
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  TOT_SALES  PERCENT_OF_TOT
# 0            Budget  MIDAGE SINGLES/COUPLES   35514.80        1.837180
# 1            Budget            NEW FAMILIES   21928.45        1.134358
# 2            Budget          OLDER FAMILIES  168363.25        8.709428
# 3            Budget   OLDER SINGLES/COUPLES  136769.80        7.075099
# 4            Budget                RETIREES  113147.80        5.853133
# 5            Budget          YOUNG FAMILIES  139345.85        7.208358
# 6            Budget   YOUNG SINGLES/COUPLES   61141.60        3.162854
# 7        Mainstream  MIDAGE SINGLES/COUPLES   90803.85        4.697281
# 8        Mainstream            NEW FAMILIES   17013.90        0.880129
# 9        Mainstream          OLDER FAMILIES  103445.55        5.351236
# 10       Mainstream   OLDER SINGLES/COUPLES  133393.80        6.900459
# 11       Mainstream                RETIREES  155677.05        8.053171
# 12       Mainstream          YOUNG FAMILIES   92788.75        4.799960
# 13       Mainstream   YOUNG SINGLES/COUPLES  157621.60        8.153762
# 14          Premium  MIDAGE SINGLES/COUPLES   58432.65        3.022720
# 15          Premium            NEW FAMILIES   11491.10        0.594434
# 16          Premium          OLDER FAMILIES   80658.40        4.172457
# 17          Premium   OLDER SINGLES/COUPLES  132263.15        6.841970
# 18          Premium                RETIREES   97646.05        5.051228
# 19          Premium          YOUNG FAMILIES   84025.50        4.346637
# 20          Premium   YOUNG SINGLES/COUPLES   41642.10        2.154145

# %%
df_4['Percent_of_TotSales']=df_5['PERCENT_OF_TOT']
df_4.head()
# Out:
#   PREMIUM_CUSTOMER               LIFESTAGE  #Transactions_Per_customer  \
# 0           Budget  MIDAGE SINGLES/COUPLES                    3.337766
# 1           Budget            NEW FAMILIES                    2.702338
# 2           Budget          OLDER FAMILIES                    4.954011
# 3           Budget   OLDER SINGLES/COUPLES                    3.734429
# 4           Budget                RETIREES                    3.412887
#
#    #packets_per_transaction  avg_price_product  Percent_of_TotSales
# 0                  1.891633           2.208977             1.837180
# 1                  1.853910           2.315103             1.134358
# 2                  1.945812           2.185014             8.709428
# 3                  1.913403           2.279435             7.075099
# 4                  1.892244           2.293559             5.853133

# %%
df_4.describe()
# Out:
#        #Transactions_Per_customer  #packets_per_transaction  \
# count                   21.000000                 21.000000
# mean                     3.634591                  1.895369
# std                      0.893475                  0.043581
# min                      2.440171                  1.803830
# 25%                      2.738516                  1.860919
# 50%                      3.412887                  1.900122
# 75%                      4.731305                  1.937732
# max                      5.031438                  1.948610
#
#        avg_price_product  Percent_of_TotSales
# count          21.000000            21.000000
# mean            2.242513             4.761905
# std             0.061544             2.518280
# min             2.150231             0.594434
# 25%             2.186601             3.022720
# 50%             2.240537             4.799960
# 75%             2.293559             6.900459
# max             2.366797             8.709428

# %%
theta1=5
theta2=10
theta3=10

# %% [markdown]
# ### Regular customers that purchases chips of reasonable price in good quantity are of greater importance than customers that visit the super-market less frequently and purchases fewer packets of expensive chips.
#
# ### Accordinly the weights are assigned to different parameters.

# %%
df_4['Score']=theta1*df_4['#Transactions_Per_customer']+theta2*df_4['#packets_per_transaction']+theta3*df_4['avg_price_product']
df_4
# Out:
#    PREMIUM_CUSTOMER               LIFESTAGE  #Transactions_Per_customer  \
# 0            Budget  MIDAGE SINGLES/COUPLES                    3.337766
# 1            Budget            NEW FAMILIES                    2.702338
# 2            Budget          OLDER FAMILIES                    4.954011
# 3            Budget   OLDER SINGLES/COUPLES                    3.734429
# 4            Budget                RETIREES                    3.412887
# 5            Budget          YOUNG FAMILIES                    4.760269
# 6            Budget   YOUNG SINGLES/COUPLES                    2.445621
# 7        Mainstream  MIDAGE SINGLES/COUPLES                    3.555090
# 8        Mainstream            NEW FAMILIES                    2.738516
# 9        Mainstream          OLDER FAMILIES                    5.031438
# 10       Mainstream   OLDER SINGLES/COUPLES                    3.715619
# 11       Mainstream                RETIREES                    3.313166
# 12       Mainstream          YOUNG FAMILIES                    4.731305
# 13       Mainstream   YOUNG SINGLES/COUPLES                    2.578388
# 14          Premium  MIDAGE SINGLES/COUPLES                    3.379679
# 15          Premium            NEW FAMILIES                    2.702381
# 16          Premium          OLDER FAMILIES                    4.920844
# 17          Premium   OLDER SINGLES/COUPLES                    3.737684
# 18          Premium                RETIREES                    3.382231
# 19          Premium          YOUNG FAMILIES                    4.752569
# 20          Premium   YOUNG SINGLES/COUPLES                    2.440171
#
#     #packets_per_transaction  avg_price_product  Percent_of_TotSales  \
# 0                   1.891633           2.208977             1.837180
# 1                   1.853910           2.315103             1.134358
# 2                   1.945812           2.185014             8.709428
# 3                   1.913403           2.279435             7.075099
# 4                   1.892244           2.293559             5.853133
# 5                   1.940749           2.196196             7.208358
# 6                   1.803830           2.150231             3.162854
# 7                   1.911656           2.323948             4.697281
# 8                   1.857634           2.304687             0.880129
# 9                   1.948610           2.186601             5.351236
# 10                  1.910525           2.240537             6.900459
# 11                  1.887543           2.252479             8.053171
# 12                  1.940342           2.183497             4.799960
# 13                  1.852498           2.366797             8.153762
# 14                  1.889727           2.212461             3.022720
# 15                  1.860919           2.282236             0.594434
# 16                  1.945576           2.180378             4.172457
# 17                  1.914273           2.270361             6.841970
# 18                  1.900122           2.296230             5.051228
# 19                  1.937732           2.208919             4.346637
# 20                  1.804012           2.155132             2.154145
#
#         Score
# 0   57.694937
# 1   55.201825
# 2   66.078315
# 3   60.600520
# 4   58.922462
# 5   65.170792
# 6   51.768712
# 7   60.131485
# 8   55.315797
# 9   66.509293
# 10  60.088715
# 11  57.966047
# 12  64.894923
# 13  55.084891
# 14  57.920279
# 15  54.943455
# 16  65.863770
# 17  60.534762
# 18  58.874679
# 19  65.229354
# 20  51.792295

# %%
df_4.describe()
# Out:
#        #Transactions_Per_customer  #packets_per_transaction  \
# count                   21.000000                 21.000000
# mean                     3.634591                  1.895369
# std                      0.893475                  0.043581
# min                      2.440171                  1.803830
# 25%                      2.738516                  1.860919
# 50%                      3.412887                  1.900122
# 75%                      4.731305                  1.937732
# max                      5.031438                  1.948610
#
#        avg_price_product  Percent_of_TotSales      Score
# count          21.000000            21.000000  21.000000
# mean            2.242513             4.761905  59.551777
# std             0.061544             2.518280   4.659461
# min             2.150231             0.594434  51.768712
# 25%             2.186601             3.022720  55.315797
# 50%             2.240537             4.799960  58.922462
# 75%             2.293559             6.900459  64.894923
# max             2.366797             8.709428  66.509293

# %%
df_4[(df_4['Score']>60.5)&(df_4['Percent_of_TotSales']>4)]
# Out:
#    PREMIUM_CUSTOMER              LIFESTAGE  #Transactions_Per_customer  \
# 2            Budget         OLDER FAMILIES                    4.954011
# 3            Budget  OLDER SINGLES/COUPLES                    3.734429
# 5            Budget         YOUNG FAMILIES                    4.760269
# 9        Mainstream         OLDER FAMILIES                    5.031438
# 12       Mainstream         YOUNG FAMILIES                    4.731305
# 16          Premium         OLDER FAMILIES                    4.920844
# 17          Premium  OLDER SINGLES/COUPLES                    3.737684
# 19          Premium         YOUNG FAMILIES                    4.752569
#
#     #packets_per_transaction  avg_price_product  Percent_of_TotSales  \
# 2                   1.945812           2.185014             8.709428
# 3                   1.913403           2.279435             7.075099
# 5                   1.940749           2.196196             7.208358
# 9                   1.948610           2.186601             5.351236
# 12                  1.940342           2.183497             4.799960
# 16                  1.945576           2.180378             4.172457
# 17                  1.914273           2.270361             6.841970
# 19                  1.937732           2.208919             4.346637
#
#         Score
# 2   66.078315
# 3   60.600520
# 5   65.170792
# 9   66.509293
# 12  64.894923
# 16  65.863770
# 17  60.534762
# 19  65.229354

# %% [markdown]
# ### Percent_of_TotSales is highly dependent on  #Transactions_Per_customer,  #packets_per_transaction, avg_price_product,  and is also highly sensitive to outliers , for example , if a customer of a particular category purchased expensive chips manier times from the store, but most other customers of that category does'nt purchase chips frequently , and also purchase fewer chips of relatively less price in single transaction ,then also that category of customers can have a higher contribution in Total_sales of chips, because of few customers.
#
# ### Because of this , I have selected category of customers based on their 'Scores'  and  'Percent_of_TotSales' both.

# %%
df_main_customers=df_4[(df_4['Score']>60.5)&(df_4['Percent_of_TotSales']>4)]
df_main_customers.reset_index(inplace=True)
df_main_customers.drop('index',axis=1,inplace=True)
df_main_customers
# Out:
# c:\users\91709\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#   PREMIUM_CUSTOMER              LIFESTAGE  #Transactions_Per_customer  \
# 0           Budget         OLDER FAMILIES                    4.954011
# 1           Budget  OLDER SINGLES/COUPLES                    3.734429
# 2           Budget         YOUNG FAMILIES                    4.760269
# 3       Mainstream         OLDER FAMILIES                    5.031438
# 4       Mainstream         YOUNG FAMILIES                    4.731305
# 5          Premium         OLDER FAMILIES                    4.920844
# 6          Premium  OLDER SINGLES/COUPLES                    3.737684
# 7          Premium         YOUNG FAMILIES                    4.752569
#
#    #packets_per_transaction  avg_price_product  Percent_of_TotSales      Score
# 0                  1.945812           2.185014             8.709428  66.078315
# 1                  1.913403           2.279435             7.075099  60.600520
# 2                  1.940749           2.196196             7.208358  65.170792
# 3                  1.948610           2.186601             5.351236  66.509293
# 4                  1.940342           2.183497             4.799960  64.894923
# 5                  1.945576           2.180378             4.172457  65.863770
# 6                  1.914273           2.270361             6.841970  60.534762
# 7                  1.937732           2.208919             4.346637  65.229354

# %%
plt.figure(figsize=(35,30))

for i in range(df_main_customers.shape[0]):
    lst=[]
    for j in df.PROD_FLAVOUR.unique():
        num=df[(df.PREMIUM_CUSTOMER==df_main_customers.iloc[i].PREMIUM_CUSTOMER)&(df.LIFESTAGE==df_main_customers.iloc[i].LIFESTAGE)&(df.PROD_FLAVOUR==j)]['PROD_QTY'].sum()
        lst.append(num)
    plt.subplot(4,2,i+1)
    plt.pie(lst,labels=list(df.PROD_FLAVOUR.unique()),autopct='%.2f%%')
    plt.title(df_main_customers.iloc[i].PREMIUM_CUSTOMER+' '+df_main_customers.iloc[i].LIFESTAGE)
plt.show()

# %% [markdown]
# ### We can see that Young and Older families are the majors chips buyers , and by above pie-charts we can also say that all imp categories of customers are fond of flavours like Cheese, Chilli, Salty, while Tomato or tangy flavour is less purchased .

# %% [markdown]
# ### Therefore the super-market needs to maintain their chips stock according to the choice of their major chip buying customer categories.

# %%
df_main_customers.to_csv('main_customers_category.csv')
